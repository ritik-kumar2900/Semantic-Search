# %%
# !pip install sentence-transformers
#installing the library
# Out:
# Collecting sentence-transformers
#   Downloading https://files.pythonhosted.org/packages/35/aa/f672ce489063c4ee7a566ebac1b723c53ac0cea19d9e36599cc241d8ed56/sentence-transformers-1.0.4.tar.gz (74kB)
#      |████████████████████████████████| 81kB 3.8MB/s
# Collecting transformers<5.0.0,>=3.1.0
#   Downloading https://files.pythonhosted.org/packages/d8/b2/57495b5309f09fa501866e225c84532d1fd89536ea62406b2181933fb418/transformers-4.5.1-py3-none-any.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 6.6MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.41.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.2.5)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 22.7MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (20.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (3.0.12)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (3.10.0)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/08/cd/342e584ee544d044fb573ae697404ce22ede086c9e87ce5960772084cad0/sacremoses-0.0.44.tar.gz (862kB)
#      |████████████████████████████████| 870kB 36.8MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/ae/04/5b870f26a858552025a62f1649c20d29d2672c02ff3c3fb4c688ca46467a/tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 38.7MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=3.1.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers) (3.7.4.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<5.0.0,>=3.1.0->sentence-transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers<5.0.0,>=3.1.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=3.1.0->sentence-transformers) (7.1.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=3.1.0->sentence-transformers) (2020.12.5)
# Building wheels for collected packages: sentence-transformers, sacremoses
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-1.0.4-cp37-none-any.whl size=114307 sha256=999a65b18b9c0afca4fd2c2f1eb7adc5dd0fb3f90a5acd2ddcedacb741381f2e
#   Stored in directory: /root/.cache/pip/wheels/26/ea/89/d0d2e013d951b6d23270aa9ca4018b82632ab7cd933c331316
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.44-cp37-none-any.whl size=886084 sha256=61ccec03bf15abd52f7a1a19bfddd8bf3a561cde07e16519d89359905327f6aa
#   Stored in directory: /root/.cache/pip/wheels/3e/fb/c0/13ab4d63d537658f448366744654323077c4d90069b6512f3c
# Successfully built sentence-transformers sacremoses
# Installing collected packages: sacremoses, tokenizers, transformers, sentencepiece, sentence-transformers
# Successfully installed sacremoses-0.0.44 sentence-transformers-1.0.4 sentencepiece-0.1.95 tokenizers-0.10.2 transformers-4.5.1

# %%
#transformers is a prerequisite for sentence transformer
from torch import nn
from transformers import AutoModel, AutoTokenizer, AutoConfig
import json
from typing import List, Dict, Optional, Union, Tuple
import os
 
 
class Transformer(nn.Module):
    """Huggingface AutoModel to generate token embeddings.
    Loads the correct class, e.g. BERT / RoBERTa etc.
 
    :param model_name_or_path: Huggingface models name 
    :param max_seq_length: Truncate any inputs longer than max_seq_length
    :param model_args: Arguments (key, value pairs) passed to the Huggingface Transformers model
    :param cache_dir: Cache dir for Huggingface Transformers to store/load models
    :param tokenizer_args: Arguments (key, value pairs) passed to the Huggingface Tokenizer model
    :param do_lower_case: Lowercase the input
    """
    def __init__(self, model_name_or_path: str, max_seq_length: int = 128,
                 model_args: Dict = {}, cache_dir: Optional[str] = None,
                 tokenizer_args: Dict = {}, do_lower_case: Optional[bool] = None):
        super(Transformer, self).__init__()
        self.config_keys = ['max_seq_length']
        self.max_seq_length = max_seq_length
 
        if do_lower_case is not None:
            tokenizer_args['do_lower_case'] = do_lower_case
 
        config = AutoConfig.from_pretrained(model_name_or_path, **model_args, cache_dir=cache_dir)
        self.auto_model = AutoModel.from_pretrained(model_name_or_path, config=config, cache_dir=cache_dir)
        self.tokenizer = AutoTokenizer.from_pretrained(model_name_or_path, cache_dir=cache_dir, **tokenizer_args)
 
 
    def forward(self, features):
        """Returns token_embeddings, cls_token"""
        trans_features = {'input_ids': features['input_ids'], 'attention_mask': features['attention_mask']}
        if 'token_type_ids' in features:
            trans_features['token_type_ids'] = features['token_type_ids']
 
        output_states = self.auto_model(**trans_features, return_dict=False)
        output_tokens = output_states[0]
 
        cls_tokens = output_tokens[:, 0, :]  # CLS token is first token
        features.update({'token_embeddings': output_tokens, 'cls_token_embeddings': cls_tokens, 'attention_mask': features['attention_mask']})
 
        if self.auto_model.config.output_hidden_states:
            all_layer_idx = 2
            if len(output_states) < 3: #Some models only output last_hidden_states and all_hidden_states
                all_layer_idx = 1
 
            hidden_states = output_states[all_layer_idx]
            features.update({'all_layer_embeddings': hidden_states})
 
        return features
 
    def get_word_embedding_dimension(self) -> int:
        return self.auto_model.config.hidden_size
 
    def tokenize(self, texts: Union[List[str], List[Tuple[str, str]]]):
        """
        Tokenizes a text and maps tokens to token-ids
        """
        output = {}
        if isinstance(texts[0], str):
            to_tokenize = [texts]
        elif isinstance(texts[0], dict):
            to_tokenize = []
            output['text_keys'] = []
            for lookup in texts:
                text_key, text = next(iter(lookup.items()))
                to_tokenize.append(text)
                output['text_keys'].append(text_key)
            to_tokenize = [to_tokenize]
        else:
            batch1, batch2 = [], []
            for text_tuple in texts:
                batch1.append(text_tuple[0])
                batch2.append(text_tuple[1])
            to_tokenize = [batch1, batch2]
 
        output.update(self.tokenizer(*to_tokenize, padding=True, truncation='longest_first', return_tensors="pt", max_length=self.max_seq_length))
        return output
 
 
    def get_config_dict(self):
        return {key: self.__dict__[key] for key in self.config_keys}
 
    def save(self, output_path: str):
        self.auto_model.save_pretrained(output_path)
        self.tokenizer.save_pretrained(output_path)
 
        with open(os.path.join(output_path, 'sentence_bert_config.json'), 'w') as fOut:
            json.dump(self.get_config_dict(), fOut, indent=2)
 
    @staticmethod
    def load(input_path: str):
        #Old classes used other config names than 'sentence_bert_config.json'
        for config_name in ['sentence_bert_config.json', 'sentence_roberta_config.json', 'sentence_distilbert_config.json', 'sentence_camembert_config.json', 'sentence_albert_config.json', 'sentence_xlm-roberta_config.json', 'sentence_xlnet_config.json']:
            sbert_config_path = os.path.join(input_path, config_name)
            if os.path.exists(sbert_config_path):
                break
 
        with open(sbert_config_path) as fIn:
            config = json.load(fIn)
        return Transformer(model_name_or_path=input_path, **config)

# %%
import scipy

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=405234788.0), HTML(value='')))

# %%
import os
import csv
import scipy

# %%
#mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#loading dataset
with open('/content/drive/MyDrive/Book3 - Copy.csv') as f:
    reader = csv.reader(f)
    fulldata = list(reader)
sentence_embeddings = model.encode(fulldata)

# %%
#@title Sematic Search Form
#enter query for search
query = 'google' #@param {type: 'string'}

queries = [query]
query_embeddings = model.encode(queries)


print("Semantic Search Results")

for query, query_embedding in zip(queries, query_embeddings):
  #setting up distances for results
    distances = scipy.spatial.distance.cdist([query_embedding], sentence_embeddings, "cosine")[0]

    results = zip(range(len(distances)), distances)
    #sorting on the basis of distance
    results = sorted(results, key=lambda x: x[1])

    print("\n\n======================\n\n")
    print("Query:", query)
    #data structure of our result data
    print(type(fulldata))
    for idx, distance in results:
      #setting the threshold
      if distance<0.5:
        print(fulldata[idx], "(Cosine Score: %.4f)" % (1-distance))
# Out:
# Semantic Search Results
#
#
# ======================
#
#
# Query: google
# <class 'list'>
# ['Google Trends', 'Google', 'https://www.npmjs.com/package/google-trends-api', 'The Google Trends API offers a layer for Google Trends data. It can be used to retrieve keyword popularity data by location, and date. This API makes use of several methods such as returning the current top 20 trending topics for a desired location (hotTrends), returning the top 30 searches of the last month (top30in30), or returning data by category (categoryTopCharts).', '2', '16', 'News & Media'] (Cosine Score: 0.9131)
# ['Google People API', 'Google', 'https://developers.google.com/people/', "The People API lets you list and manage the authenticated user's Contacts and retrieve profile information for authenticated users and their contacts.", '2', '6', 'Social Media & Technology'] (Cosine Score: 0.9000)
# ['Google+ API', 'Google', 'https://developers.google.com/+/web/', 'The Google+ API is the programming interface to Google+. This enables users to connect with each other for maximum engagement using Google+ features.', '2', '6', 'Social Media & Technology'] (Cosine Score: 0.8955)
# ['Gmail API', 'Google', 'https://developers.google.com/gmail/api/guides/', "The Gmail API is a RESTful API that can be used to access Gmail mailboxes and send mail. For most web applications (including mobile apps), the Gmail API is the best choice for authorized access to a user's Gmail data.", '2', '6', 'Social Media & Technology'] (Cosine Score: 0.8935)
# ['Google Sheets API', 'Google', 'https://developers.google.com/sheets/', "Google Sheets is an online spreadsheet app that lets users create and format spreadsheets and simultaneously work with other people. Google Sheets isn’t only for consumers: it's used every day by businesses and schools to manage spreadsheet data. With the new Sheets API v4 and Sheets add-ons, that data can be accessed by code as well as users.", '2', '5', 'Software & Services'] (Cosine Score: 0.8869)
# ['Google Partners API', 'Google', 'https://developers.google.com/partners/', 'The Google Partners API lets advertisers search certified companies and create contact leads with them, and also audits the usage of clients.', '2', '15', 'Information & Science'] (Cosine Score: 0.8849)
# ['Google Translate API', 'Google', 'https://cloud.google.com/translate/docs/reference/rest', 'Cloud Translation API provides a simple programmatic interface for translating an arbitrary string into any supported language using state-of-the-art Neural Machine Translation. Translation API is highly responsive, so websites and applications can integrate with Translation API for fast, dynamic translation of source text from the source language to a target language (e.g., French to English). Language detection is also available in cases where the source language is unknown. The underlying technology pushes the boundary of Machine Translation and is updated constantly to seamlessly improve translations and introduce new languages and language pairs.', '2', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.8818)
# ['Google Calendar API', 'Google', 'https://developers.google.com/calendar/v3/reference/', "Use the Google Calendar API to find and view public calendar events. If you're authorized, you can also access and modify private calendars and events on those calendars.", '2', '15', 'Information & Science'] (Cosine Score: 0.8721)
# ['My Google Book API', 'My Google', 'https://developers.google.com/books/docs/v1/reference/volumes#resource', 'A Volume represents information that Google Books hosts about a book or magazine and includes all metadata such as author, publisher, etc.', '261', '15', 'Information & Science'] (Cosine Score: 0.8651)
# ['Google Books API', 'Google', 'https://developers.google.com/books/docs/v1/reference/volumes#resource', 'A Volume represents information that Google Books hosts about a book or magazine and includes all metadata such as author, publisher, etc.', '2', '15', 'Information & Science'] (Cosine Score: 0.8641)
# ['Google Maps Directions API', 'Google', 'https://developers.google.com/maps/documentation/directions/start', 'The Google Maps Directions API is a service that calculates directions between locations. You can search for directions for several modes of transportation, including transit, driving, walking, or cycling.', '2', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.8552)
# ['Google Fit History API', 'Google', 'https://developers.google.com/fit/android/history', 'The History API enables your app to perform bulk operations on the fitness store: reading, inserting, updating, and deleting fitness data. Use the History API to:_x005F_x000D_\n_x005F_x000D_\nRead fitness data that was inserted or recorded using other apps._x005F_x000D_\nImport batch data into Google Fit._x005F_x000D_\nUpdate data in Google Fit._x005F_x000D_\nDelete data that your app previously stored in the fitness history.', '2', '18', 'Health Science & Medicine'] (Cosine Score: 0.8389)
# ['Google Apps Script API', 'Google', 'https://developers.google.com/apps-script/api/', 'The Google Apps Script API replaces and extends the Apps Script Execution API. The Apps Script API allows your apps to perform operations that previously could only be done in the Apps Script editor. With the API, your apps can do the following programmatically:_x005F_x000D_\n_x005F_x000D_\n- Create and modify Apps Script projects._x005F_x000D_\n- Deploy projects for use as web apps, add-ons, or executables._x005F_x000D_\n- Monitor script use and metrics._x005F_x000D_\n- Execute Apps Script functions remotely.', '2', '5', 'Software & Services'] (Cosine Score: 0.8378)
# ['Google Geocoding API', 'Google', 'https://developers.google.com/maps/documentation/geocoding/start', 'The Geocoding API is a service that provides geocoding and reverse geocoding of addresses. _x005F_x000D_\nGeocoding is the process of converting addresses (like a street address) into geographic coordinates (like latitude and longitude), which you can use to place markers on a map, or position the map._x005F_x000D_\nReverse geocoding is the process of converting geographic coordinates into a human-readable address._x005F_x000D_\nYou can also use the Geocoding API to find the address for a given place ID.', '2', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.8353)
# ['Civic Information API', 'Google', 'https://developers.google.com/civic-information/docs/v2/', 'The Google Civic Information API lets developers build applications that display civic information to their users. For any U.S. residential address, you can look up who represents that address at each elected level of government. During supported elections, you can also look up polling places, early vote location, candidate data, and other election official information.', '2', '3', 'Government & Public Services'] (Cosine Score: 0.8337)
# ['Google-- Google Books API Swagger', 'My Google', 'www.homepage.com', 'Description Goes here', '261', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.8282)
# ['Google URL Shortener API', 'Google', 'https://developers.google.com/url-shortener/v1/getting_started', 'The Google URL Shortener at goo.gl is a service that takes long URLs and squeezes them into fewer characters to make a link that is easier to share, tweet, or email to friends. Users can create these short links through the web interface at goo.gl, or they can programatically create them through the URL Shortener API. With the URL Shortener API you can write applications that use simple HTTP methods to create, inspect, and manage goo.gl short links from desktop, mobile, or web.', '2', '5', 'Software & Services'] (Cosine Score: 0.8192)
# ['Google Cloud Billing API', 'Google', 'https://cloud.google.com/billing/docs/', 'Allows developers to manage billing for their Google Cloud Platform projects programmatically.', '2', '11', 'Finance & Banking'] (Cosine Score: 0.8079)
# ['YouTube Data API', 'Google', 'https://developers.google.com/youtube/v3/docs/', 'The YouTube Data API lets you incorporate functions normally executed on the YouTube website into your own website or application. The lists below identify the different types of resources that you can retrieve using the API. The API also supports methods to insert, update, or delete many of these resources.', '2', '6', 'Social Media & Technology'] (Cosine Score: 0.8073)
# ['Google Cloud Text-to-Speech API', 'Google', 'https://cloud.google.com/text-to-speech/docs/reference/rest/', 'Translate the input text into a natural-sounding speech by applying powerful neural network models.', '2', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.7283)
# ['Google Cloud Speech-to-Text API', 'Google', 'https://cloud.google.com/speech-to-text/', 'Speech-to-text conversion powered by machine learning and available for short-form or long-form audio.', '2', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.7221)
# ['Sell Analytics API', 'eBay', 'https://developer.ebay.com/api-docs/sell/analytics/resources/methods', 'The Analytics API provides data about a seller and their business, including performance data on their items listings and information on their eBay seller rating.', '68', '20', 'eCommerce & Trade'] (Cosine Score: 0.6767)
# ['MediaWiki Search API', 'Wikipedia', 'https://www.mediawiki.org/wiki/API:Search', 'To search on wikipedia with some specific keyword.', '56', '16', 'News & Media'] (Cosine Score: 0.6720)
# ['Mapquest Search API', 'Mapquest - Verizon', 'https://developer.mapquest.com/documentation/search-api/v2/', 'The Search API allows spatial searches on hosted data utilizing the MapQuest Data Manager and remote data.', '105', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.6706)
# ['Mapquest Search Ahead API', 'Mapquest - Verizon', 'https://developer.mapquest.com/documentation/searchahead-api/get/', 'This endpoint returns a list of suggestions, or predictions, based on two or more characters provided with the request.', '105', '15', 'Information & Science'] (Cosine Score: 0.6664)
# ['Instagram API', 'Instagram', 'https://www.instagram.com/developer/', 'The Instagram API Platform can be used to build non-automated, authentic, high-quality apps and services that:_x005F_x000D_\n_x005F_x000D_\n    Help individuals share their own content with 3rd party apps._x005F_x000D_\n    Help brands and advertisers understand, manage their audience and media rights._x005F_x000D_\n    Help broadcasters and publishers discover content, get digital rights to media, and share media with proper attribution.', '17', '6', 'Social Media & Technology'] (Cosine Score: 0.6592)
# ['Twitter Search API', 'Twitter', 'https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets', 'Returns a collection of relevant Tweets matching a specified query.', '6', '6', 'Social Media & Technology'] (Cosine Score: 0.6555)
# ['Github API', 'Github', 'https://developer.github.com/v3/', 'GitHub is a repository of public open source and private business code. Is is a fast, efficient, distributed version control system ideal for the collaborative development of software. Use it to fork projects, send pull requests, monitor development.', '13', '5', 'Software & Services'] (Cosine Score: 0.6509)
# ['Mapquest Icon API', 'Mapquest - Verizon', 'https://developer.mapquest.com/documentation/icons-api/v2/', 'Icon types including markers, circles, vias, and flags that can be used in both our Static Map API or our MapQuest Plugins for Leaflet.', '105', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6482)
# ['Reddit History API', 'Reddit', 'https://www.reddit.com/dev/api/oauth#GET_user_{username}_comments', "Access my voting history and comments or submissions I've saved or hidden.", '44', '6', 'Social Media & Technology'] (Cosine Score: 0.6447)
# ['CVE_Search', 'Circl', 'https://www.circl.lu/services/cve-search/', 'Test', '268', '2', 'Security & Technology'] (Cosine Score: 0.6432)
# ['Github Users API', 'Github', 'https://developer.github.com/v3/users/', 'Many of the resources on the users API provide a shortcut for getting information about the currently authenticated user. If a request URL does not include a :username parameter then the response will be for the logged in user (and you must pass authentication information with your request). Additional private information, such as whether a user has two-factor authentication enabled, is included when authenticated through basic auth or OAuth.', '13', '5', 'Software & Services'] (Cosine Score: 0.6402)
# ['GPS traces API', 'OpenStreetMap', 'https://wiki.openstreetmap.org/wiki/API_v0.6#GPS_traces', 'The following command returns, in GPX format, the GPS track points that are inside a given bounding box.', '59', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6401)
# ['Bing Maps Location API', 'Microsoft - Bing Maps', 'https://msdn.microsoft.com/en-us/library/ff701715.aspx', 'Use the Locations API to get location information.', '18', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6396)
# ['Sell Account API', 'eBay', 'https://developer.ebay.com/docs', "The Account API gives sellers the ability to configure their eBay seller accounts, including the seller's policies (the Fulfillment Policy, Payment Policy, and Return Policy), opt in and out of eBay seller programs, configure sales tax tables, and get account information.", '68', '20', 'eCommerce & Trade'] (Cosine Score: 0.6383)
# ['Reddit Read API', 'Reddit', 'https://www.reddit.com/dev/api/oauth#GET_api_info', 'Access posts and comments through my account.', '44', '6', 'Social Media & Technology'] (Cosine Score: 0.6366)
# ['Outlook Contacts', 'Microsoft', 'https://developer.microsoft.com/en-us/graph/docs/api-reference/v1.0/resources/contact', 'A contact is an item in Outlook where you can organize and save information about the people and organizations you communicate with. Contacts are contained in contact folders.', '4', '6', 'Social Media & Technology'] (Cosine Score: 0.6359)
# ['Twitter Trends API', 'Twitter', 'https://developer.twitter.com/en/docs/trends/trends-for-location/overview', 'An API to return the trending topics near a specific latitude, longitude location.', '6', '6', 'Social Media & Technology'] (Cosine Score: 0.6355)
# ['Github GraphQL API', 'Github', 'https://developer.github.com/v4/', "The GraphQL data query language is:_x005F_x000D_\n_x005F_x000D_\nA specification. The spec determines the validity of the schema on the API server. The schema determines the validity of client calls._x005F_x000D_\n_x005F_x000D_\nStrongly typed. The schema defines an API's type system and all object relationships._x005F_x000D_\n_x005F_x000D_\nIntrospective. A client can query the schema for details about the schema._x005F_x000D_\n_x005F_x000D_\nHierarchical. The shape of a GraphQL call mirrors the shape of the JSON data it returns. Nested fields let you query for and receive only the data you specify in a single round trip._x005F_x000D_\n_x005F_x000D_\nAn application layer. GraphQL is not a storage model or a database query language. The graph refers to graph structures defined in the schema, where nodes define objects and edges define relationships between objects. The API traverses and returns application data based on the schema definitions, independent of how the data is stored.", '13', '5', 'Software & Services'] (Cosine Score: 0.6339)
# ['Mapquest Direction API', 'Mapquest - Verizon', 'https://developer.mapquest.com/documentation/directions-api/', 'The Directions API provides a simple interface to get routing, narrative, and shapes.', '105', '5', 'Software & Services'] (Cosine Score: 0.6336)
# ['Vimeo Projects API', 'Vimeo', 'https://developer.vimeo.com/api/reference/ondemand', 'Vimeo On Demand', '28', '6', 'Social Media & Technology'] (Cosine Score: 0.6333)
# ['Mapquest Geocoding API', 'Mapquest - Verizon', 'https://developer.mapquest.com/documentation/geocoding-api/address/get/', 'The geocoding service enables you to take an address and get the associated latitude and longitude.', '105', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6329)
# ['Twilio Mesaages Resource Chat API', 'Twilio', 'https://www.twilio.com/docs/chat/rest/messages', 'The Message resource of Programmable Chat represents a single message within a Channel in a Service instance.', '55', '6', 'Social Media & Technology'] (Cosine Score: 0.6313)
# ['Github Comments API', 'Github', 'https://developer.github.com/v3/gists/comments/#get-a-single-comment', 'Gist Comments use these custom media types. You can read more about the use of media types in the API here.', '13', '5', 'Software & Services'] (Cosine Score: 0.6310)
# ['MediaWiki basics API', 'Wikipedia', 'https://www.mediawiki.org/wiki/API:Query', 'https://www.mediawiki.org/wiki/API:Query', '56', '16', 'News & Media'] (Cosine Score: 0.6300)
# ['API Search', 'APIs.io', 'http://apis.io/apiDoc', 'APIs.io allows to get/add from their v1 API. Root domain for the API is http://apis.io/api/', '257', '5', 'Software & Services'] (Cosine Score: 0.6270)
# ['OneDrive', 'Microsoft', 'https://developer.microsoft.com/en-us/graph/docs/api-reference/v1.0/resources/onedrive', 'Use Microsoft Graph to create an app that connects with files across OneDrive, OneDrive for Business, and SharePoint document libraries.', '4', '5', 'Software & Services'] (Cosine Score: 0.6261)
# ['Bing Maps Elevations API', 'Microsoft - Bing Maps', 'https://msdn.microsoft.com/en-us/library/jj158959.aspx', 'Get elevation information for a set of locations, polyline or area on the Earth.', '18', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6252)
# ['Github Notifications API', 'Github', 'https://developer.github.com/v3/activity/notifications/', 'Users receive notifications for conversations in repositories they watch including:_x005F_x000D_\n_x005F_x000D_\nIssues and their comments_x005F_x000D_\nPull Requests and their comments_x005F_x000D_\nComments on any commits', '13', '5', 'Software & Services'] (Cosine Score: 0.6250)
# ['Clarifai Search API', 'Clarifai', 'https://clarifai.com/developer/guide/', '', '63', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.6249)
# ['Reddit Identity API', 'Reddit', 'https://www.reddit.com/dev/api/oauth#scope_account', 'Update preferences and related account information. Will not have access to your email or password.', '44', '6', 'Social Media & Technology'] (Cosine Score: 0.6236)
# ['Sell Fullfillment API', 'eBay', 'https://developer.ebay.com/api-docs/sell/fulfillment/resources/methods', 'Use the Fulfillment API to complete the process of packaging, addressing, handling, and shipping each order on behalf of the seller, in accordance with the payment method and timing specified at checkout.', '68', '20', 'eCommerce & Trade'] (Cosine Score: 0.6234)
# ['Microsoft Graph', 'Microsoft', 'https://developer.microsoft.com/en-us/graph/docs/concepts/overview', 'You can use the Microsoft Graph API to interact with the data of millions of users in the Microsoft cloud. Use Microsoft Graph to build apps for organizations and consumers that connect to a wealth of resources, relationships, and intelligence, all through a single endpoint.', '4', '5', 'Software & Services'] (Cosine Score: 0.6229)
# ['Bing Maps Imagery API', 'Microsoft - Bing Maps', 'https://msdn.microsoft.com/en-us/library/ff701721.aspx', 'Get static maps and Bing™ Maps imagery information.', '18', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6217)
# ['Github Activity Feeds API', 'Github', 'https://developer.github.com/v3/activity/feeds/', 'The Feeds API lists all the feeds available to the authenticated user:_x005F_x000D_\nTimeline: The GitHub global public timeline_x005F_x000D_\nUser: The public timeline for any user, using URI template_x005F_x000D_\nCurrent user public: The public timeline for the authenticated user_x005F_x000D_\nCurrent user: The private timeline for the authenticated user_x005F_x000D_\nCurrent user actor: The private timeline for activity created by the authenticated user_x005F_x000D_\nCurrent user organizations: The private timeline for the organizations the authenticated user is a member of.', '13', '5', 'Software & Services'] (Cosine Score: 0.6217)
# ['OpenDota API', 'OpenDota', 'https://docs.opendota.com/', '', '184', '17', 'Sports & Entertainment'] (Cosine Score: 0.6211)
# ['Miscellaneous API', 'OpenStreetMap', 'https://wiki.openstreetmap.org/wiki/API_v0.6#URL_.2B_authentication', '', '59', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6211)
# ['MediaWiki Authentication API', 'Wikipedia', 'https://www.mediawiki.org/wiki/API:Tokens', 'To obtain tokens required by data-modifying actions.', '56', '16', 'News & Media'] (Cosine Score: 0.6205)
# ['iTunes Search API', 'Apple', 'https://affiliate.itunes.apple.com/resources/documentation/itunes-store-web-service-search-api/', 'The Search API allows you to place search for content within the iTunes Store, App Store, iBooks Store and Mac App Store. You can search for a variety of content; including apps, iBooks, movies, podcasts, music, music videos, audiobooks, and TV shows.', '3', '5', 'Software & Services'] (Cosine Score: 0.6185)
# ['quickGo Annotation API', 'EMBL-EBI', 'https://www.ebi.ac.uk/QuickGO/api/index.html#/annotations', 'Return information on Annotation services', '103', '5', 'Software & Services'] (Cosine Score: 0.6171)
# ['Vimeo Groups Api', 'Vimeo', 'https://developer.vimeo.com/api/reference/groups', 'Vimeo Groups.', '28', '6', 'Social Media & Technology'] (Cosine Score: 0.6166)
# ['OneNote', 'Microsoft', 'https://developer.microsoft.com/en-us/graph/docs/api-reference/v1.0/resources/onenote-api-overview', "Microsoft Graph lets your app get authorized access to a user's OneNote notebooks, sections, and pages in a personal or organization account. With the appropriate delegated or application permissions, your app can access the OneNote data of the signed-in user or any user in a tenant.", '4', '5', 'Software & Services'] (Cosine Score: 0.6166)
# ['Search REST API', 'Algolia', 'https://www.algolia.com/doc/rest-api/search/', '', '159', '5', 'Software & Services'] (Cosine Score: 0.6164)
# ['Web Domain Name', 'Enclout', 'https://www.enclout.com/', 'EnClout Ignite brings the power of web APIs to Microsoft Excel and Google Sheets using custom functions. With our Ignite framework, you can:_x005F_x000D_\n_x005F_x000D_\n Retrieve data from web services as Custom Functions._x005F_x000D_\n Support web services with XML or JSON outputs._x005F_x000D_\n Support parameters from by GET, POST and HTTP headers._x005F_x000D_\n Minimum Learning curve regardless of the underlying APIs_x005F_x000D_\n Chain multiple APIs using standard spreadsheet features', '123', '5', 'Software & Services'] (Cosine Score: 0.6159)
# ['Bing Maps Routes API', 'Microsoft - Bing Maps', 'http://msdn.microsoft.com/en-us/library/ff701705.aspx', 'Use the Routes API to create a route that includes two or more locations and to create routes from major roads.', '18', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6157)
# ['Imgur API', 'Imgur', 'https://api.imgur.com/', 'Share photos using Imgur and its API. There are two options: anonymous upload or OAuth upload, which connects your photos to your account and gives your app twice the number of uploads per hour.', '12', '6', 'Social Media & Technology'] (Cosine Score: 0.6153)
# ['Mapquest Traffic API', 'Mapquest - Verizon', 'https://developer.mapquest.com/documentation/traffic-api/', 'The Traffic Service provides real time traffic information related to markets, incidents, and flow.', '105', '9', 'Transportation & Automobile'] (Cosine Score: 0.6138)
# ['Project Rome', 'Microsoft', 'https://developer.microsoft.com/en-us/graph/docs/api-reference/v1.0/resources/project_rome_overview', 'Project Rome is a Microsoft initiative to build a cross-device experiences platform. Project Rome enables an app on a local client or service to interact with apps and services on a remote host when the user signs in with the same Microsoft account that they use to sign in on the client device. This allows you to program cross-device and cross-platform experiences that are centered around user tasks rather than devices._x005F_x000D_\nA key component is exposed via Microsoft Graph to enable these experiences: activities.', '4', '5', 'Software & Services'] (Cosine Score: 0.6135)
# ['Bing Maps Traffic API', 'Microsoft - Bing Maps', 'https://msdn.microsoft.com/en-us/library/hh441725.aspx', 'Get information about traffic incidents and issues, such as construction sites and traffic congestion.', '18', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6130)
# ['Changesets API', 'OpenStreetMap', 'https://wiki.openstreetmap.org/wiki/API_v0.6#Changesets_2', '', '59', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6112)
# ['Pinterest Users API', 'Pinterest', 'https://developers.pinterest.com/docs/api/users/', 'Use the API to fetch profile info, boards, suggested boards and Pins, as well as search boards and Pins for authenticated users. You can also create, fetch and delete followers and following relationships for authenticated users.', '25', '6', 'Social Media & Technology'] (Cosine Score: 0.6102)
# ['Github Gists API', 'Github', 'https://developer.github.com/v3/gists/#list-a-users-gists', "you can share single files, parts of files, and full applications with other people. Directories can't be shared._x005F_x000D_\nEvery gist is a Git repository, which means that it can be forked and cloned. The gist editor is powered by CodeMirror.", '13', '5', 'Software & Services'] (Cosine Score: 0.6101)
# ['Web Services API', 'Last.fm', 'https://www.last.fm/', '', '188', '5', 'Software & Services'] (Cosine Score: 0.6100)
# ['MediaWiki Page Operations API', 'Wikipedia', 'https://www.mediawiki.org/wiki/API:Parsing_wikitext', 'To parse content of a page and obtain the output.', '56', '16', 'News & Media'] (Cosine Score: 0.6099)
# ['api', 'Hello World', 'https://www.api.com', 'api', '264', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.6093)
# ['Mapquest Static Map API', 'Mapquest - Verizon', 'https://developer.mapquest.com/documentation/static-map-api/v5/map/', 'Get map data.', '105', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6092)
# ['Github Issues API', 'Github', 'https://developer.github.com/v3/issues/#list-issues', 'Issues use these custom media types.', '13', '5', 'Software & Services'] (Cosine Score: 0.6074)
# ['Microsoft-- Microsoft Graph Swagger', 'test_vendor', 'www.homepage.com', 'Description Goes here', '262', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.6074)
# ['SMS API', 'Onehop', 'http://api.onehop.co/api-docs/?python#send-sms', 'Onehop is a provider of SMS messaging, SMS aggregation, analytics and other messaging solutions. The Onehop SMS API provides access to a variety of messaging functionalities such as account management, business analytics, campaigns, routing configuration, and SMS history & delivery reports. It is a RESTful API that conveys requests and responses in JSON format.', '125', '19', 'Business & Technology'] (Cosine Score: 0.6066)
# ['quickGo Ontology API', 'EMBL-EBI', 'https://www.ebi.ac.uk/QuickGO/api/index.html', "The QuickGO REST API provides access to key biological data from QuickGO and GOA. The services provide a unified interface to query information about ontology terms from GO (the Gene Ontology) and ECO (the Evidence & Conclusion Ontology), Gene Ontology annotations from the EBI's GOA database, and gene products (proteins from UniProt, RNA from RNAcentral and complexes from ComplexPortal).", '103', '5', 'Software & Services'] (Cosine Score: 0.6054)
# ['Elements API', 'OpenStreetMap', 'https://wiki.openstreetmap.org/wiki/API_v0.6#Elements_2', 'There are create, read, update and delete calls for all of the three basic elements in OpenStreetMap (Nodes, Ways and Relations).', '59', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6050)
# ['Microsoft Translator API', 'Microsoft', 'https://www.microsoft.com/en-us/translator/translatorapi.aspx', 'Microsoft Translator Text API, part of Microsoft Cognitive Services, is a cloud-based machine translation service supporting more than 60 languages. Translator can be used to build applications, websites, tools, or any solution requiring multi-language support.', '4', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.6050)
# ['Yahoo Query Language', 'Yahoo', 'https://developer.yahoo.com/yql/', 'The YQL (Yahoo! Query Language) platform enables you to query, filter, and combine data across the web through a single interface. It exposes a SQL-like syntax that is both familiar to developers and expressive enough for getting the right data.', '20', '5', 'Software & Services'] (Cosine Score: 0.6035)
# ['BuiltWith Domain API', 'BuiltWith', 'https://api.builtwith.com/domain-api', 'The BuiltWith Domain API provides XML and JSON access to the technology information of a website which includes all technical information as found on detailed lookups at builtwith.com and additional meta data where available.', '231', '5', 'Software & Services'] (Cosine Score: 0.6030)
# ['Sell Compliance API', 'eBay', 'https://developer.ebay.com/api-docs/sell/compliance/overview.html', "The Compliance API is used to retrieve listing violations for three different compliance types. Once listing violations are discovered in active listings for the seller, it is up to the seller to make revisions to these listings to correct the listing violations. The three different listing compliance types are summarized below:_x005F_x000D_\n_x005F_x000D_\nProduct Adoption: this compliance type is used to see if any listings (or variations within multiple-variation listings) are violating eBay's new Product-Based Commerce requirement. As of May 2018, some eBay categories and product brands started requiring that sellers list those products using an eBay catalog product. If a seller does not use a catalog product for categories/brands applicable to the Product-Based Commerce requirement, a create or revise listing action will be blocked. For more information on the Product-Based Shopping Experience mandate, see the Product-Based Shopping Experience Playbook. The Product Adoption compliance type also applies to any listings (or variations within multiple-variation listings) that are missing product identifiers in item specifics, and when variations within multiple-variation listings are wrongfully sharing the same identifier values. In the API interface, the enumeration value for this compliance type is PRODUCT_ADOPTION._x005F_x000D_\nHTTPS protocol: this compliance type is used to see if any listings are violating eBay's policy of using HTTP links in the listing description instead of HTTPS links. This requirement includes links to externally-hosted listing images. If the server hosting the listing images does not support the HTTPS protocol, this server cannot be used to host listing images. In the API interface, the enumeration value for this compliance type is HTTPS._x005F_x000D_\nNon-eBay Links: this compliance type is used to see if any listings are violating eBay's policy of not allowing links in the listing description to sites outside of eBay. The seller including a personal email address and/or a phone number in the listing description is also a violation of this policy. All communication between seller and buyers should be handled through eBay's communication system. The only exceptions to this outside links rule are links to product videos, information on freight shipping services, or any legally required information. In the API interface, the enumeration value for this compliance type is OUTSIDE_EBAY_BUYING_AND_SELLING.", '68', '20', 'eCommerce & Trade'] (Cosine Score: 0.6030)
# ['Algorithmia API', 'Algorithmia', 'https://docs.algorithmia.com/', 'Deploy and Manage ML Models the Smart Way.', '161', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.6023)
# ['User Data API', 'OpenStreetMap', 'https://wiki.openstreetmap.org/wiki/API_v0.6#Methods_for_user_data', 'Details of a user', '59', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.6023)
# ['Mapquest Data Manager API', 'Mapquest - Verizon', 'https://developer.mapquest.com/documentation/data-manager/', 'Data Manager tables must be created prior to uploading data. This section of the Data Manager API documentation describes how to create, copy, and delete tables. It also describes the data types supported by the Data Manager API as well as table visibility; meaning, tables can be made public to all MapQuest developers or private and viewable only by the table owner.', '105', '5', 'Software & Services'] (Cosine Score: 0.6010)
# ['Facebook Groups API', 'Facebook', 'https://developers.facebook.com/docs/groups-api', 'The Groups API is a collection of Graph API endpoints that let you read and create Facebook Group data on behalf of group members._x005F_x000D_\n_x005F_x000D_\nBy installing your app on a group, a group admin can grant your app access to group content, such as posts, photos, and videos, and allow you to publish content to the group on behalf of the admin. Admins can also allow you to access publicly available information about group members who have chosen to share their public information with apps installed on the group.', '8', '6', 'Social Media & Technology'] (Cosine Score: 0.6001)
# ['NYTimes Article Search API', 'NYTimes', 'https://developer.nytimes.com/docs/articlesearch-product/1/overview', 'Use the Article Search API to look up articles by keyword. You can refine your search using filters and facets.', '213', '16', 'News & Media'] (Cosine Score: 0.5996)
# ['Linkedin People API', 'LinkedIn', 'https://developer.linkedin.com/docs/rest-api', 'Linkedin People.', '36', '6', 'Social Media & Technology'] (Cosine Score: 0.5993)
# ['OpenML API', 'OpenML', 'https://www.openml.org/', 'REST API for sharing, organizing and reusing machine learning datasets, code, and experiments.', '233', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.5984)
# ['SearchCVE', 'TeejLab', 'https://teejlab.com', 'TeejLab', '277', '2', 'Security & Technology'] (Cosine Score: 0.5983)
# ['WebShrinker Screenshot API', 'WebShrinker', 'https://docs.webshrinker.com/v2/website-screenshot-api.html#screenshot-api-introduction', 'The Web Shrinker screenshots API gives developers the ability to capture an image of what a particular website looks like in a browser window. You can then include these images in your own web pages or do some other processing on them in your preferred programming language. This technique has been used on many popular sites including the major search engines.', '73', '5', 'Software & Services'] (Cosine Score: 0.5973)
# ['Github Activity Starring API', 'Github', 'https://developer.github.com/v3/activity/starring/#list-stargazers', 'Repository Starring is a feature that lets users bookmark repositories. Stars are shown next to repositories to show an approximate level of interest. Stars have no effect on notifications or the activity feed. For that, see Repository Watching.', '13', '5', 'Software & Services'] (Cosine Score: 0.5965)
# ['Vimeo Channels API', 'Vimeo', 'https://developer.vimeo.com/api/reference/channels', 'Vimeo Channels.', '28', '6', 'Social Media & Technology'] (Cosine Score: 0.5963)
# ['WebShrinker Website Domain API', 'WebShrinker', 'https://docs.webshrinker.com/v3/website-domain-api.html#website-domain-api-introduction', 'The Web Shrinker Domain API gives developers the ability to retrieve information about a given domain name, including its main categories, primary language, hosting server IP addresses, known sub-domain names, as well as inbound and outbound hyperlinks.', '73', '5', 'Software & Services'] (Cosine Score: 0.5960)
# ['Twilio Channels Resource Chat API', 'Twilio', 'https://www.twilio.com/docs/chat/rest/channels', 'The Channel resource of Programmable Chat represents a "chat room" - a scope in which Messages can be sent and received.', '55', '6', 'Social Media & Technology'] (Cosine Score: 0.5946)
# ['Github Git Data API', 'Github', 'https://developer.github.com/v3/git/', 'The Git Database API gives you access to read and write raw Git objects to your Git database on GitHub and to list and update your references (branch heads and tags)._x005F_x000D_\nThis basically allows you to reimplement a lot of Git functionality over our API - by creating raw objects directly into the database and updating branch references you could technically do just about anything that Git can do without having Git installed.', '13', '5', 'Software & Services'] (Cosine Score: 0.5939)
# ['Github Activity Events API', 'Github', 'https://developer.github.com/v3/activity/', "Serving up the 'social' in Social Coding, the Activity APIs provide access to notifications, subscriptions, and timelines.", '13', '5', 'Software & Services'] (Cosine Score: 0.5928)
# ['Disqus Posts API', 'Disqus', 'https://disqus.com/api/docs/posts/', 'Gives access to posts (comments).', '40', '6', 'Social Media & Technology'] (Cosine Score: 0.5924)
# ['Facebook Pages API', 'Facebook', 'https://developers.facebook.com/docs/pages/getting-started', "With the Pages API people can update and manage Facebook Pages from your page-related app. People can publish content to Facebook or Messenger with a Page's identity. Use cases for Pages API include:_x005F_x000D_\n_x005F_x000D_\nBuilding a Pages management tool for customers or for your company_x005F_x000D_\nBuilding apps so content creators and editors can easily publish as a Page_x005F_x000D_\nMarketing and advertising for a business using the Marketing API.", '8', '6', 'Social Media & Technology'] (Cosine Score: 0.5921)
# ['Ifixit API', 'Ifixit', 'https://zh.ifixit.com/api/2.0/doc/', 'Our API provides programmatic access to iFixit, enabling anyone to write innovative applications and utilities on top of our rich database.', '226', '5', 'Software & Services'] (Cosine Score: 0.5915)
# ['Yahoo Gemini API', 'Yahoo', 'https://developer.yahoo.com/gemini/', 'Yahoo Gemini is the unified marketplace bringing mobile search and native ads together. Gemini API allows advertisers to manage complex Gemini accounts and campaigns more efficiently.', '20', '19', 'Business & Technology'] (Cosine Score: 0.5913)
# ['Reddit Subreddits API', 'Reddit', 'https://www.reddit.com/dev/api/oauth#POST_api_live_{thread}_accept_contributor_invite', 'Access the list of subreddits I moderate, contribute to, and subscribe to.', '44', '6', 'Social Media & Technology'] (Cosine Score: 0.5905)
# ['GWS API', 'GlobalWinescore', 'https://globalwinescore.docs.apiary.io/#reference/globalwinescore/gws/list-all-latest-gws', 'Returns the latest GWS available per wine/vintage.', '82', '15', 'Information & Science'] (Cosine Score: 0.5899)
# ['Linkedin People API', 'test_vendor', 'https://www.linkedin.com/developers/apps/5334785/auth', 'https://www.linkedin.com/developers/apps/5334785/auth', '262', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.5887)
# ['Cloudmersive-- Image Recognition and Processing API Swagger', 'test_vendor', 'www.homepage.com', 'Description Goes here', '262', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.5882)
# ['DBPedia SPARQL API', 'DBPedia', 'https://dbpedia.org/sparql', 'Query DBPedia using SPARQL.', '48', '15', 'Information & Science'] (Cosine Score: 0.5880)
# ['Marketplace App API', 'Atlassian - Marketplace', 'https://developer.atlassian.com/platform/marketplace/rest/#api-group-Apps', 'Information about apps.', '52', '5', 'Software & Services'] (Cosine Score: 0.5866)
# ['Vimeo Categories API', 'Vimeo', 'https://developer.vimeo.com/api/reference/categories', 'Categories.', '28', '6', 'Social Media & Technology'] (Cosine Score: 0.5850)
# ['WebShrinker Website Category API', 'WebShrinker', 'https://docs.webshrinker.com/v3/website-category-api.html#website-category-api-introduction', 'The Web Shrinker Category API gives developers the ability to lookup the categories that a particular URL, website, domain name, or IP address is categorized as.', '73', '5', 'Software & Services'] (Cosine Score: 0.5845)
# ['Facebook Graph API', 'Facebook', 'https://developers.facebook.com/docs/graph-api', 'The Graph API is the primary way for apps to read and write to the Facebook social graph. All of our SDKs and products interact with the Graph API in some way, and our other APIs are extensions of the Graph API, so understanding how the Graph API works is crucial.', '8', '6', 'Social Media & Technology'] (Cosine Score: 0.5845)
# ['Facebook Graph API', 'Facebook', 'https://developers.facebook.com/docs/graph-api/reference', 'The Graph API is the primary way for apps to read and write to the Facebook social graph. All of our SDKs and products interact with the Graph API in some way, and our other APIs are extensions of the Graph API, so understanding how the Graph API works is crucial.', '8', '6', 'Social Media & Technology'] (Cosine Score: 0.5845)
# ['Facebook Graph API', 'Facebook', 'https://developers.facebook.com/docs/graph-api', 'The Graph API is the primary way for apps to read and write to the Facebook social graph. All of our SDKs and products interact with the Graph API in some way, and our other APIs are extensions of the Graph API, so understanding how the Graph API works is crucial.', '8', '6', 'Social Media & Technology'] (Cosine Score: 0.5845)
# ['Github Checks API', 'Github', 'https://developer.github.com/v3/checks/', 'Send detailed information about the checks your integrations run with the Checks API. Rather than binary pass/fail build statuses, integrations can report rich statuses, annotate lines of code with detailed information, and kick off reruns. The Checks API functionality is available exclusively to your GitHub Apps.', '13', '5', 'Software & Services'] (Cosine Score: 0.5832)
# ['Mercury Web Parser API', 'Mercury Postlight', 'https://mercury.postlight.com/web-parser/', 'Mercury takes any web article and returns only the relevant content — headline, author, body text, relevant images and more — free from any clutter.', '99', '16', 'News & Media'] (Cosine Score: 0.5827)
# ['Marketplace App Versions API', 'Atlassian - Marketplace', 'https://developer.atlassian.com/platform/marketplace/rest/#api-addons-addonKey-versions-get', 'Information about app versions.', '52', '5', 'Software & Services'] (Cosine Score: 0.5825)
# ['NDEx User API', 'NDEx', 'http://www.home.ndexbio.org/using-the-ndex-server-api/', 'Get User’s Membership in Group.', '54', '15', 'Information & Science'] (Cosine Score: 0.5805)
# ['Pushbullet Subscription API', 'Pushbullet', 'https://docs.pushbullet.com/#subscription', 'Subscribe to channels to receive any updates pushed to that channel.', '43', '19', 'Business & Technology'] (Cosine Score: 0.5800)
# ['Bitbucket User API', 'Atlassian - Bitbucket', 'https://developer.atlassian.com/bitbucket/api/2/reference/resource/', 'Bitbucket Cloud REST Users API.', '49', '5', 'Software & Services'] (Cosine Score: 0.5798)
# ['Wordpress Posts API', 'Wordpress', 'https://developer.wordpress.com/docs/api/1.1/get/sites/%24site/posts/%24post_ID/', 'View and manage posts including reblogs and likes.', '27', '6', 'Social Media & Technology'] (Cosine Score: 0.5788)
# ['Tumblr Blog Methods API', 'Tumblr', 'https://www.tumblr.com/docs/en/api/v2#blog_methods', 'This method returns general information about the blog, such as the title, number of posts, and other high-level data.', '46', '6', 'Social Media & Technology'] (Cosine Score: 0.5786)
# ['Open Notify Space API', 'Open Notify', 'http://open-notify.org/Open-Notify-API/', 'Open Notify is an open source project to provide a simple programming interface for some of NASA’s awesome data. I do some of the work to take raw data and turn them into APIs related to space and spacecraft.', '14', '15', 'Information & Science'] (Cosine Score: 0.5777)
# ['Open Library Search API', 'Open Library', 'https://openlibrary.org/dev/docs/api/search', 'Open Library provides an experimental API to search.', '98', '16', 'News & Media'] (Cosine Score: 0.5776)
# ['WebTRIS Traffic Sites API', 'Highway England', 'http://webtris.highwaysengland.co.uk/api/swagger/ui/index#!/Sites/Sites_Index', 'Get a list of sites._x005F_x000D_\n_x005F_x000D_\nNOTE: The WebTRIS data available at http://webtris.highwaysengland.co.uk/ is available via an application programming interface (API) in JSON format. This is a free service and there is no need to register to use it. Developers can utilise the WebTRIS data to provide their own services, applications and websites.', '94', '9', 'Transportation & Automobile'] (Cosine Score: 0.5760)
# ['Open AQ Platform API', 'OpenAQ', 'https://docs.openaq.org/#api-_', 'Open Air Quality (AQ) empowers communities to end air inequality through open data. OpenAQ-aggregates data that are gathered in real-time from government agencies. No guarantees are made though for their accuracy. All quality control measures should be done by the user or by contacting the host source. This API is used to power various tools built by the community as well as openaq.org.', '116', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.5757)
# ['OpenRouteService API', 'OpenRouteService', 'https://openrouteservice.org/dev/#/api-docs', 'ORS offers global spatial services by utilizing user-generated and collaboratively collected free geographic data from OpenStreetMap. The API comprises a geocoding, directions, locations and isochrones endpoint allowing you to consume its results in your applications.', '218', '5', 'Software & Services'] (Cosine Score: 0.5756)
# ['Pushbullet Chat API', 'Pushbullet', 'https://docs.pushbullet.com/#chat', 'Chats are created whenever you send a message to someone or a receive a message from them and there is no existing chat between you and the other user.', '43', '6', 'Social Media & Technology'] (Cosine Score: 0.5756)
# ['Clearbit Autocomplete API', 'Clearbit', 'https://dashboard.clearbit.com/docs#autocomplete-api', 'Company Autocomplete is a free API that lets you auto-complete company names and retrieve logo and domain information. _x005F_x000D_\n_x005F_x000D_\n(Note that this API use an Basic Auth, where the username is your secret key and password is blank).', '224', '15', 'Information & Science'] (Cosine Score: 0.5747)
# ['Sell Inventory API', 'eBay', 'https://developer.ebay.com/api-docs/sell/inventory/resources/location/methods/getInventoryLocation', 'This call retrieves all defined details of the inventory location that is specified by the merchantLocationKey path parameter.', '68', '20', 'eCommerce & Trade'] (Cosine Score: 0.5743)
# ['IGDB Page API', 'IGDB', 'https://api-docs.igdb.com/?shell#page', 'The IGDB page information.', '199', '17', 'Sports & Entertainment'] (Cosine Score: 0.5732)
# ['Builds API', 'JitPack', 'https://jitpack.io/docs/API/', 'Get all builds for a project and build outcomes.', '280', '19', 'Business & Technology'] (Cosine Score: 0.5729)
# ['BuiltWith Trends API', 'BuiltWith', 'https://api.builtwith.com/trends-api', 'The BuiltWith Trends API provides XML and JSON access to the technology trends data found on BuiltWith Trends.', '231', '5', 'Software & Services'] (Cosine Score: 0.5727)
# ['OpenSecrets API', 'OpenSecrets', 'https://www.opensecrets.org/open-data/api', "The OpenSecrets API provides access to the data displayed on OpenSecrets.org. OpenSecrets performs research to track money in U.S. politics and its effect on elections and public policy. Use the API to access a politician's top contributors, personal financial disclosures for a politician, and more.", '243', '3', 'Government & Public Services'] (Cosine Score: 0.5725)
# ['The Guardian Content API', 'The Guardian', 'https://open-platform.theguardian.com/access/', 'To get all the laest news around the world in json format.', '61', '16', 'News & Media'] (Cosine Score: 0.5721)
# ...
# ['Table Usage API', 'Quandl', 'https://docs.quandl.com/docs/in-depth-usage-1', 'It is possible to download only certain desired rows from a table, by specifying one or more columns to act as criteria to filter rows. If the value in a given column matches the filter argument, then the row containing that value is returned.', '60', '15', 'Information & Science'] (Cosine Score: 0.5163)
# ['BuiltWith Company to URL', 'BuiltWith', 'https://api.builtwith.com/company-to-url', 'Get domain names from lists of company names you supply to us.', '231', '5', 'Software & Services'] (Cosine Score: 0.5162)
# ['Address Validation API', 'Byteplant', 'https://www.address-validator.net/', 'To save money on mailing and shipping, you need to verify address information right at the point of entry. Integrating our Realtime Global Address Validation API directly into your website or eCommerce application allows your customers to correct errors instantly and only valid addresses will be accepted.', '157', '5', 'Software & Services'] (Cosine Score: 0.5162)
# ['NASA EONET API', 'NASA', 'https://eonet.sci.gsfc.nasa.gov/docs/v2.1', 'More and more NASA imagery is being made available via web services (WMS, WMTS, etc.) and a significant percentage of it is being produced and published in near real time (NRT = within a few hours after acquisition). This ability means that NASA imagery can be used more routinely to examine current natural events as they happen._x005F_x000D_\n_x005F_x000D_\nUsing client applications, such as NASA EOSDIS’ Worldview, users can browse the entire globe daily and look for natural events as they occur. Storms are regularly spotted in the tropics, dust storms over deserts, forest fires in the summers. These events are occurring constantly and NASA NRT imagery can represent them all using a variety of different data parameters. However, the user’s experience is tailored, and therefore restricted, by the client application. What if there was an API that provided a curated list of natural events and provided a way to link those events to event-related NRT image layers? Enter EONET._x005F_x000D_\n_x005F_x000D_\nThe Earth Observatory Natural Event Tracker (EONET) is a prototype web service with the goal of:_x005F_x000D_\n_x005F_x000D_\nproviding a curated source of continuously updated natural event metadata; providing a service that links those natural events to thematically-related web service-enabled image sources (e.g., via WMS, WMTS, etc.). Please see our API documentation to learn more about how to use the EONET web services.', '15', '15', 'Information & Science'] (Cosine Score: 0.5159)
# ['Pinterest Pins API', 'Pinterest', 'https://developers.pinterest.com/docs/api/pins/', 'Use the API to create, edit and delete Pins for authenticated users. It can be also used to fetch Pins, boards and the Pins on a board for any user.', '25', '6', 'Social Media & Technology'] (Cosine Score: 0.5157)
# ['Visual Recognition Face API', 'IBM Watson', 'https://console.bluemix.net/apidocs/visual-recognition#detect-faces-in-an-image', 'On April 2, 2018, the identity information in the response to calls to the Face model was removed. The identity information refers to the name of the person, score, and type_hierarchy knowledge graph. For details about the enhanced Face model, see the Release notes._x005F_x000D_\n_x005F_x000D_\nAnalyze and get data about faces in images. Responses can include estimated age and gender. This feature uses a built-in model, so no training is necessary. The Detect faces method does not support general biometric facial recognition.', '57', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.5145)
# ['Vimeo Likes API', 'Vimeo', 'https://developer.vimeo.com/api/reference/likes', 'Vimeo Likes.', '28', '6', 'Social Media & Technology'] (Cosine Score: 0.5138)
# ['BuiltWith Relationships API', 'BuiltWith', 'https://api.builtwith.com/relationships-api', 'Get XML and JSON results of relationships between websites that show what sites are linked together, by what and for how long.', '231', '5', 'Software & Services'] (Cosine Score: 0.5136)
# ['QRCode Generation API', 'NeutrinoAPI', 'https://www.neutrinoapi.com/api/qr-code/', 'Generate a QR code as a PNG image', '258', '19', 'Business & Technology'] (Cosine Score: 0.5129)
# ['Tags Calls API', 'Mandrill', 'https://mandrillapp.com/api/docs/tags.JSON.html', 'Return all of the user-defined tag information', '42', '5', 'Software & Services'] (Cosine Score: 0.5128)
# ['Warp World Entry API', 'Maker of Mario', 'https://forum.warp.world/t/unofficial-api-docs/3787', 'API entry, including a list of a few endpoints.', '190', '17', 'Sports & Entertainment'] (Cosine Score: 0.5127)
# ['Box Users API', 'Box', 'https://developer.box.com/reference', 'The users endpoint is used for managing a user and its content. For an individual user, this includes their own user information and content. For an enterprise admin, this includes both the individual user and any other users in the admin’s enterprise account.', '41', '5', 'Software & Services'] (Cosine Score: 0.5127)
# ['Flickr Activity API', 'Flickr', 'https://www.flickr.com/services/api/', 'Returns a list of recent activity.', '47', '6', 'Social Media & Technology'] (Cosine Score: 0.5122)
# ['Mandrill Urls Calls API', 'Mandrill', 'https://mandrillapp.com/api/docs/urls.JSON.html', 'Get the 100 most clicked URLs.', '42', '5', 'Software & Services'] (Cosine Score: 0.5116)
# ['Gitlab Snippets API', 'Gitlab', 'https://docs.gitlab.com/ee/api/snippets.html', 'Snippets in GitLab can be either private, internal, or public. You can set it with the visibility field in the snippet.', '24', '5', 'Software & Services'] (Cosine Score: 0.5108)
# ['Gitlab Issue Boards API', 'Gitlab', 'https://docs.gitlab.com/ee/api/boards.html', 'Every API call to boards must be authenticated._x005F_x000D_\nIf a user is not a member of a project and the project is private, a GET request on that project will result to a 404 status code.', '24', '5', 'Software & Services'] (Cosine Score: 0.5102)
# ['Open Library Books API', 'Open Library', 'https://openlibrary.org/developers/api', 'Open Library has developed a suite of APIs to help developers get up and running with our data.', '98', '16', 'News & Media'] (Cosine Score: 0.5091)
# ['IP Check', 'Apility', 'https://apility.io/apidocs/#ip-check', "Check if an IP belongs to any abusers' blacklist. Apility.io tracks multiple abuse blacklists and consolidates them in a single database you can look up with our minimalist API.", '259', '2', 'Security & Technology'] (Cosine Score: 0.5090)
# ['Filestack', 'Filestack', 'https://www.filestack.com/docs/api/file/', '', '217', '5', 'Software & Services'] (Cosine Score: 0.5088)
# ['Visual Recognition Custom API', 'IBM Watson', 'https://console.bluemix.net/apidocs/visual-recognition#retrieve-a-list-of-classifiers', 'Train a new multi-faceted classifier on the uploaded image data. Create your custom classifier with positive or negative examples. Include at least two sets of examples, either two positive example files or one positive and one negative file. You can upload a maximum of 256 MB per call.', '57', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.5086)
# ['USPTO Data Set API', 'USPTO', 'https://developer.uspto.gov/ds-api-docs/index.html?url=https%3A//developer.uspto.gov/ds-api/swagger/docs/oce_patent_examination_event_codes.json#/', 'The Data Set API (DSAPI) allows the public users to discover and search USPTO exported data sets. This is a generic API that allows USPTO users to make any CSV based data files searchable through API. With the help of GET call, it returns the list of data fields that are searchable.', '65', '3', 'Government & Public Services'] (Cosine Score: 0.5085)
# ['CarpoolWorld API', 'CarpoolWorld', 'https://www.carpoolworld.com/documentation/developer_api.html', "CarpoolWorld brings people together for ridesharing, using a pioneering search engine that matches individuals based on their trip origins and destinations, anywhere on the planet. The CarpoolWorld API gives developers access to the web site's essential functions to create trips, find matches, and contact potential travel partners. The API is developed using the RESTful style. Responses are formatted in XML.", '202', '9', 'Transportation & Automobile'] (Cosine Score: 0.5083)
# ['Gitlab Labels API', 'Gitlab', 'https://docs.gitlab.com/ee/api/labels.html', 'Get all labels for a given project.', '24', '5', 'Software & Services'] (Cosine Score: 0.5067)
# ['Word Associations API', 'Word Associations', 'https://wordassociations.net/en/api-doc', 'This document is written for developers who want to add word associations lookup feature to their websites or apps.', '95', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.5066)
# ['OKCoin Spot Price API', 'OKCoin', 'https://support.okcoin.com/hc/en-us/articles/360000697832-REST-API-Reference', 'Receive the latest OKCoin spot market data.', '229', '20', 'eCommerce & Trade'] (Cosine Score: 0.5065)
# ['IoT Plotting API', 'IoTPlotter', 'https://iotplotter.com/docs/#introduction', 'IoTPlotter is a service which collects data from your IoT devices for long-term graph plotting and storage.Features: (1) Long-term history allows you to compare old data to new data. (2) Completely free so anybody can get involved right away. (3) Simple APIs allow you to connect any internet enabled device. (4) Responsive graphs allow you to visualize your data intuitively. (5) Scalable design to accommodate large numbers of users and devices.', '115', '15', 'Information & Science'] (Cosine Score: 0.5062)
# ['Tables COMPOSITION OF A CALL API', 'Quandl', 'https://docs.quandl.com/docs/quick-start-examples-9', 'The following call retrieves the complete history of revenue per share for Nokia in XML format from the Mergent Global Fundamentals Data (MF1) table.', '60', '16', 'News & Media'] (Cosine Score: 0.5060)
# ['Spotify Album API', 'Spotify', 'https://api.spotify.com/v1/albums/{id}', 'Get the album information from Spotify', '196', '17', 'Sports & Entertainment'] (Cosine Score: 0.5056)
# ['Adafruit IO REST API', 'Adafruit', 'https://io.adafruit.com/api/docs/', 'The Internet of Things for Everyone_x005F_x000D_\nThe Adafruit IO HTTP API provides access to your Adafruit IO data from any programming language or hardware environment that can speak HTTP. The easiest way to get started is with an Adafruit IO learn guide and a simple Internet of Things capable device like the Feather Huzzah.', '166', '5', 'Software & Services'] (Cosine Score: 0.5046)
# ['Twilio Studio Execution API', 'Twilio', 'https://www.twilio.com/docs/studio/rest-api/execution', 'An Execution represents a specific person’s run through a Flow. An execution is active while the user is in the Flow, and it is considered ended when they stop or are kicked out of the Flow.', '55', '6', 'Social Media & Technology'] (Cosine Score: 0.5043)
# ['Gitlab Group Badges API', 'Gitlab', 'https://docs.gitlab.com/ee/api/group_badges.html', "Badges support placeholders that will be replaced in real time in both the link and image URL. The allowed placeholders are:_x005F_x000D_\n%{project_path}: will be replaced by the project path._x005F_x000D_\n%{project_id}: will be replaced by the project id._x005F_x000D_\n%{default_branch}: will be replaced by the project default branch._x005F_x000D_\n%{commit_sha}: will be replaced by the last project's commit sha.", '24', '5', 'Software & Services'] (Cosine Score: 0.5034)
# ['Atlassian Confluence Group API', 'Atlassian - Confluence', 'https://developer.atlassian.com/cloud/confluence/rest/#api-group-Group', 'Returns all user groups.', '53', '5', 'Software & Services'] (Cosine Score: 0.5027)
# ['Address Autocomplete API', 'Allies', 'https://developers.alliescomputing.com/postcoder-web-api/address-lookup/address-autocomplete', 'Provides as-you-type address suggestions and then a retrieve step to return a full address._x005F_x000D_\n_x005F_x000D_\nSupports both UK and Irish addresses.', '154', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.5027)
# ['Makers of Mario API', 'Maker of Mario', 'https://forum.warp.world/t/unofficial-api-docs/3787', 'Include endpoints for stats of Maker of Mario', '190', '17', 'Sports & Entertainment'] (Cosine Score: 0.5024)
# ['Atlassian Confluence Settings API', 'Atlassian - Confluence', 'https://developer.atlassian.com/cloud/confluence/rest/#api-group-Settings', 'Returns the look and feel settings for the site or a single space. This includes attributes such as the color scheme, padding, and border radius.', '53', '5', 'Software & Services'] (Cosine Score: 0.5024)
# ['Mobile Phone Number Validation API', 'Allies', 'https://developers.alliescomputing.com/postcoder-web-api/mobile-validation', 'Validate mobile phone numbers, see which network they are connected to and see if they have been connected in the last 12 hours.', '154', '6', 'Social Media & Technology'] (Cosine Score: 0.5021)
# ['Twilio Step Context Studio API', 'Twilio', 'https://www.twilio.com/docs/studio/rest-api/step-context#fetch-a-single-step-context', 'ExecutionStepContext properties.', '55', '6', 'Social Media & Technology'] (Cosine Score: 0.5018)
# ['Cryptocurrency API', 'Coinpaprika', 'https://coinpaprika.com/api/', 'Coinpaprika Cryptocurrency API tracks the world of cryptocurrencies and present data in the most simplistic way through a web platform. The base endpoint is: https://api.coinpaprika.com/v1/. All endpoints return either a JSON object or array. All timestamp related fields are in seconds', '120', '11', 'Finance & Banking'] (Cosine Score: 0.5014)
# ['Discovery Tranning Data API', 'IBM Watson', 'https://www.ibm.com/watson/developercloud/discovery/api/v1/curl.html?curl#training-data-api', 'Add training data to your collection to improve the relevance of query results. Note: When working with training data, use the training array returned by the list collection details method to check the status of training, including the number of training data examples, whether the service has enough valid training data to provide improved relevance of returned results, and other relevance-training details.', '57', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.5014)
# ['The Guardian Tags API', 'The Guardian', 'https://open-platform.theguardian.com/access/', 'Returns news regarding specific tag provided or in general provides all tags if no tag is specified.', '61', '16', 'News & Media'] (Cosine Score: 0.5013)
# ['UK Postcode to Geodata API', 'Allies', 'https://developers.alliescomputing.com/postcoder-web-api/geocoding/position', 'Returns latitude and longitude coordinates (ETRS89 / WGS84 / Google Maps format) and grid references from a postcode (e.g. NR14 7PZ).', '154', '12', 'GeoInformatics & Navigation'] (Cosine Score: 0.5006)
# ['Time-Series Usage API', 'Quandl', 'https://docs.quandl.com/docs/in-depth-usage', 'This call returns data from a specified time-series.', '60', '15', 'Information & Science'] (Cosine Score: 0.5002)
# ['Discovery Events & Fedback API', 'IBM Watson', 'https://www.ibm.com/watson/developercloud/discovery/api/v1/curl.html?curl#get-metrics-query', 'Query and event logs store information about natural language queries that have been made to a private collection and events associated with those queries. Each event is created using the events endpoint and must be associated with an existing natural language query. The query and event logs can be viewed using the logs endpoint, and statistics on those logs are returned by the various metrics endpoints.', '57', '4', 'Artificial Intelligence & Data Science'] (Cosine Score: 0.5001)
